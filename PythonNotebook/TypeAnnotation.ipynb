# %%
name : str = "Atıl"

# %%
type(name)
# Out:
# str

# %%
surname : str = 20

# %%
type(surname)
# Out:
# int

# %%
# :str falan filan bir önemi yok kodu değiştirmez sadece dökümantasyon okurken kolaylık olsun diye böyle yazılabillir.

# %%
name : str = "Atıl"
age : int = 30
is_student : bool = False

# %%
def add_numbers(a: int, b: int) -> int:
    return a + b

# %%
add_numbers(4,5)
# Out:
# 9

# %%
def process_value(value: int | str) -> str:
    if isinstance(value, int):
        return f"processed integer: {value} "
    else:
        return f"processed string: {value}"

# %%
process_value(50)
# Out:
# 'processed integer: 50 '

# %%
process_value("kfksddw")
# Out:
# 'processed string: kfksddw'

# %%
from typing import List

def sum_list(numbers: List[int]) -> int:
    return sum(numbers)

# %%
numbers = [1,2,3,4]

# %%
total = sum_list(numbers)

# %%
total
# Out:
# 10
