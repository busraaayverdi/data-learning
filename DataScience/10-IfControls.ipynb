# %%
 x = 5
 y = 2

# %%
x > y
# Out:
# True

# %%
y > x
# Out:
# False

# %%
y < x
# Out:
# True

# %%
y = 5

# %%
 x >= y
# Out:
# True

# %%
x <= y
# Out:
# True

# %%
x >= 5.0
# Out:
# True

# %%
x = 10
y = 8

# %%
x = y

# %%
x
# Out:
# 8

# %%
y
# Out:
# 8

# %%
x = 10

# %%
x==10
# Out:
# True

# %%
x != y
# Out:
# True

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
10 in {10,20,30}
# Out:
# True

# %%
myDict = {"a":10,"b":20,"c":30}

# %%
10 in myDict.values()
# Out:
# True

# %%
10 in myDict.keys()
# Out:
# False

# %%
my_superhero = "Batman"

# %%
my_superhero == "Batman"
# Out:
# True

# %%
my_superhero == "Superman"
# Out:
# False

# %%
if my_superhero == "Batman":
    #indentation
    print("Yes, my superhero is Batman")
    print("büşra ayverdi")
else:
    print("No, my superhero is Batman")

print("hello büşra")
# Out:
# Yes, my superhero is Batman
# büşra ayverdi
# hello büşra

# %%
my_superhero = input("enter your superhero: ")

# %%
if my_superhero == "Superman":
    print("Supermannn")
elif my_superhero == "Batman":
    print("Batmann")
elif my_superhero == "Aquaman":
    print("Aquaman")
else:
    print("nothing :( ")
# Out:
# nothing :(

# %%
age = input("enter your age: ")
age = int(age)

if age <= 18:
    print("age <= 18")
elif 30 >= age > 18:
    print("age is between 18 and 30")
else:
    print("age > 30")
# Out:
# age is between 18 and 30

# %%
my_superhero = input("enter your superhero: ")

# %%
my_superhero_list = ["Spider Man","Iron Man" "Black Widow"]

# %%
if my_superhero in my_superhero_list:
    print("Yes, my superhero is " + my_superhero)
else:
    print("No, my superhero is " + my_superhero)
# Out:
# Yes, my superhero is Spider Man
