# %%
#unique elements, unordered

# %%
myList = [10,20,30,40,10,20,30]

# %%
len(myList)
# Out:
# 7

# %%
myList
# Out:
# [10, 20, 30, 40, 10, 20, 30]

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,40,10,20,30}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
# mySet[0] yok yasak index mantığı yok

# %%
mySet2 = {30,40,50,60,70}

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2
# Out:
# {30, 40, 50, 60, 70}

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2)
# Out:
# {30, 40, 50}

# %%
countryList = ["de","fr","tr","fr","tr","fr","de","nl","de"]

# %%
len(countryList)
# Out:
# 9

# %%
set(countryList)
# Out:
# {'de', 'fr', 'nl', 'tr'}

# %%
len(set(countryList))
# Out:
# 4

# %%
emptyList = []

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptySet = {}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(10)
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)

# %%
emptySet
# Out:
# {10, 20, 30}

# %%
emptyList = list()

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyDict = dict()

# %%
emptyDict['a'] = 10
emptyDict['b'] = 20
emptyDict['c'] = 30

# %%
emptyDict
# Out:
# {'a': 10, 'b': 20, 'c': 30}
