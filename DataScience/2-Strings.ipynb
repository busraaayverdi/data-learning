# %%
print("hello world")
# Out:
# hello world

# %%
"hello world"
# Out:
# 'hello world'

# %%
x = "hello world"

# %%
x
# Out:
# 'hello world'

# %%
x = 3

# %%
x = "hello world"

# %%
x
# Out:
# 'hello world'

# %%
type(x)
# Out:
# str

# %%
len(x)
# Out:
# 11

# %%
print(x)
# Out:
# hello world

# %% [markdown]
# escape character

# %%
print("hello python")
# Out:
# hello python

# %%
print("hello \npython")
# Out:
# hello
# python

# %%
print("hello \tpython")
# Out:
# hello 	python

# %%
x.capitalize()
# Out:
# 'Hello world'

# %%
x.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x.count()
#
# TypeError: count expected at least 1 argument, got 0

# %%
x.count("l")
# Out:
# 3

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
len(x)
# Out:
# 11

# %% [markdown]
# index

# %%
myString = "hello python"

# %%
len(myString)
# Out:
# 12

# %%
myString[len(myString)-1]
# Out:
# 'n'

# %%
myString[-1]
# Out:
# 'n'

# %% [markdown]
# slicing

# %%
myString2 = "ABCDE123123982"

# %%
myString2[0]
# Out:
# 'A'

# %%
myString2[3::]
# Out:
# 'DE123123982'

# %%
myString2[:3:]
# Out:
# 'ABC'

# %%
myString2[::2]
# Out:
# 'ACE2138'

# %%
myString2[3:5:]
# Out:
# 'DE'

# %%
myString2[3:5]
# Out:
# 'DE'

# %%
myString2[1:9:2]
# Out:
# 'BD13'

# %%
myString2[::-1]
# Out:
# '289321321EDCBA'

# %%
myString.index("l")
# Out:
# 2

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
myName = "busra"

# %%
mySurname = "ayverdi"

# %%
myFullname  =myName +" "+ mySurname

# %%
print(myFullname)
# Out:
# busra ayverdi
