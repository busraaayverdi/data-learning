# %%
5*2
# Out:
# 10

# %%
5*5
# Out:
# 25

# %%
120/5
# Out:
# 24.0

# %%
age = 50

# %%
age
# Out:
# 50

# %%
age/2
# Out:
# 25.0

# %%
age*3
# Out:
# 150

# %%
#data type

# %%
type
# Out:
# type

# %%
type(10)
# Out:
# int

# %%
type(10*3)
# Out:
# int

# %%
type(age*3)
# Out:
# int

# %%
pi = 3.14

# %%
age * pi
# Out:
# 157.0

# %%
#float -> floating point
#int -> integer

# %%
x = -100

# %%
x / pi
# Out:
# -31.84713375796178

# %%
x
# Out:
# -100

# %%
x = 10

# %%
x = 20

# %%
x + 10
# Out:
# 30

# %%
myFloat = 1.36362746

# %%
r = input("r: ")

# %%
r
# Out:
# '5'

# %%
type(r)
# Out:
# str

# %%
r_int = int(r)

# %%
r
# Out:
# '5'

# %%
r_int
# Out:
# 5

# %%
type(r_int)
# Out:
# int

# %%
r_int * pi * 2
# Out:
# 31.400000000000002

# %%
10 % 2
# Out:
# 0

# %%
#remainder -> %

# %%
10%3
# Out:
# 1

# %% [markdown]
# merhaba
