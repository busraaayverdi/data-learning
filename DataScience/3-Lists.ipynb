# %%
myString = "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
#list -> koleksiyon

# %%
myString
# Out:
# 'hello python'

# %%
myString[0]
# Out:
# 'h'

# %%
# myString[0] = "a" --> stringin tek bir harfini kendi başına değiştiremezsin

# %%
#immutable - immutability

# %%
myString = "busra"

# %% [markdown]
# lists

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList = [10,20,30,30,40,50,60,70]

# %%
myList[0]
# Out:
# 10

# %%
type(myList[0])
# Out:
# int

# %%
type(myList)
# Out:
# list

# %%
myList[0]
# Out:
# 10

# %%
myList[0]=100

# %%
#mutable, mutability --> değiştirilebilir

# %%
myList
# Out:
# [100, 20, 30, 30, 40, 50, 60, 70]

# %%
len(myList)
# Out:
# 8

# %%
myList[len(myList)-1]
# Out:
# 70

# %%
myList[-1]
# Out:
# 70

# %%
myList[-2]
# Out:
# 60

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 30, 40, 50, 60, 70, 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [100, 20, 30, 30, 40, 50, 60, 70, 80, 1]

# %%
myList.count(30)
# Out:
# 2

# %%
myList.count(25)
# Out:
# 0

# %%
myList.index(40)
# Out:
# 4

# %%
myList.insert(2,35)

# %%
myList
# Out:
# [100, 20, 35, 30, 30, 40, 50, 60, 70, 80, 1]

# %%
myList.pop()
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 35, 30, 30, 40, 50, 60, 70, 80]

# %%
myList.remove(40)
myList
# Out:
# [100, 20, 35, 30, 30, 50, 60, 70, 80]

# %%
myList.reverse()
myList
# Out:
# [80, 70, 60, 50, 30, 30, 35, 20, 100]

# %%
myList.sort()
myList
# Out:
# [20, 30, 30, 35, 50, 60, 70, 80, 100]

# %%
x = input("enter x: ")

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y: ")

# %%
y
# Out:
# '20'

# %%
z = input("enter z: ")

# %%
z
# Out:
# '30'

# %%
inputList = []

# %%
inputList
# Out:
# []

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[1]
# Out:
# '20'

# %%
inputList[1] * 2
# Out:
# '2020'

# %%
type(inputList[1])
# Out:
# str

# %%
#python inputları otomatik string olarak kaydeder. Bu yüzden liste içinde bi işlem yapmaya çalıştığımızda gerektiği yerde stringten integer yada diğer variables lara dönüştürebilmeliyiz.

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "python"

# %%
#python metinleri integer a nasıl çevireceğini bilemez zaten mantıklı da değil.

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1]) * 2
# Out:
# 40

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
str(inputList)
# Out:
# "['10', '20', '30']"

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
nameList = ["busra", "anıl", "a", "b"]

# %%
nameList
# Out:
# ['busra', 'anıl', 'a', 'b']

# %%
floatList = [3.14, 2.5, 10.2, 100,123]

# %%
type(floatList)
# Out:
# list

# %%
floatList
# Out:
# [3.14, 2.5, 10.2, 100, 123]

# %%
mixedList = ["atıl",100,3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
mixedList
# Out:
# ['atıl', 100, 3.14]

# %%
mixedList[1]
# Out:
# 100

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[2])
# Out:
# float

# %%
###nestedList

# %%
myNestedList = [10, 20, 3.14, "atil", [1,2,3]]

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'atil', [1, 2, 3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'atil'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
x = myNestedList[0]
x
# Out:
# 10

# %%
smallList = myNestedList[4]
smallList
# Out:
# [1, 2, 3]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'atil', [1, 2, 3]]

# %%
myNestedList[4][1]
# Out:
# 2

# %%
lastList = ["a", "b", ["c", "d", "e"], "f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
lastList[2][1]
# Out:
# 'd'

# %%
myList
# Out:
# [20, 30, 30, 35, 50, 60, 70, 80, 100]

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList[2::]
# Out:
# [30, 40, 50, 60, 70]

# %%
firstList[:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList[::2]
# Out:
# [10, 30, 50, 70]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
