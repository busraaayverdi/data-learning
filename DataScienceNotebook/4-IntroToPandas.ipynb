# %%
#https://jalammar.github.io/gentle-visual-intro-to-data-analysis-python-pandas/

# %%
import numpy as np
import pandas as pd

# %%
#!pip install pandas
# Out:
# ^C

# %%
grades = {"Atil" : 50, "James" : 60, "Lars" : 30}

# %%
pd.Series(grades)
#dataframe kullanırız genelde çünkü dataframde serilerin birleşimidir.
# Out:
# Atil     50
# James    60
# Lars     30
# dtype: int64

# %%
names = ["Atil", "James", "Lars"]
grades = [50,60,30]

# %%
pd.Series(names)
# Out:
# 0     Atil
# 1    James
# 2     Lars
# dtype: str

# %%
pd.Series(grades)
# Out:
# 0    50
# 1    60
# 2    30
# dtype: int64

# %%
pd.Series(grades, names)
# Out:
# Atil     50
# James    60
# Lars     30
# dtype: int64

# %%
pd.Series(data=grades, index=names)
# Out:
# Atil     50
# James    60
# Lars     30
# dtype: int64

# %%
# with numpy

# %%
numpy_array = np.array([50,40,30,20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %%
#arithmetic

# %%
contest_result = pd.Series([10,5,100],["Atil","James","Lars"])

# %%
contest_result2 = pd.Series([20,50,10],["Atil","James","Lars"])

# %%
contest_result
# Out:
# Atil      10
# James      5
# Lars     100
# dtype: int64

# %%
contest_result2
# Out:
# Atil     20
# James    50
# Lars     10
# dtype: int64

# %%
contest_result["Atil"]
# Out:
# np.int64(10)

# %%
contest_result2["James"]
# Out:
# np.int64(50)

# %%
final_result = contest_result + contest_result2

# %%
final_result
# Out:
# Atil      30
# James     55
# Lars     110
# dtype: int64

# %%
contest_result * contest_result2
# Out:
# Atil      200
# James     250
# Lars     1000
# dtype: int64

# %%
contest_result - contest_result2
# Out:
# Atil    -10
# James   -45
# Lars     90
# dtype: int64

# %%
contest_result / contest_result2
# Out:
# Atil      0.5
# James     0.1
# Lars     10.0
# dtype: float64

# %%
# if indices are different

# %%
different_series = pd.Series([20,30,40,50],["a","b","c","d"])

# %%
different_series_2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
different_series + different_series_2
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
